# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ytxu\Documents\ArcGIS\Projects\GE6211SDH\LTA Data Mall\DYNAMIC\transport_node_bus_202101\transport_node_bus_202101.csv",sep=',')

# %%
df.head()
# Out:
#   YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  PT_CODE  \
# 0    2021-01  WEEKENDS/HOLIDAY              7     BUS    56061
# 1    2021-01           WEEKDAY              7     BUS    56061
# 2    2021-01           WEEKDAY              8     BUS    64179
# 3    2021-01  WEEKENDS/HOLIDAY              8     BUS    64179
# 4    2021-01  WEEKENDS/HOLIDAY             16     BUS    11551
#
#    TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME
# 0                    8                    58
# 1                   17                    53
# 2                    1                    56
# 3                    4                    16
# 4                   25                   202

# %%
df['NET_MOVEMENT'] = df['TOTAL_TAP_OUT_VOLUME'] - df['TOTAL_TAP_IN_VOLUME']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194084 entries, 0 to 194083
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   YEAR_MONTH            194084 non-null  object
#  1   DAY_TYPE              194084 non-null  object
#  2   TIME_PER_HOUR         194084 non-null  int64
#  3   PT_TYPE               194084 non-null  object
#  4   PT_CODE               194084 non-null  int64
#  5   TOTAL_TAP_IN_VOLUME   194084 non-null  int64
#  6   TOTAL_TAP_OUT_VOLUME  194084 non-null  int64
#  7   NET_MOVEMENT          194084 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 11.8+ MB

# %%
weekday = df[df['DAY_TYPE'] == 'WEEKDAY']
weekday_am_peak = weekday[weekday['TIME_PER_HOUR']==8]

# %%
weekday_am_peak.head()
# Out:
#    YEAR_MONTH DAY_TYPE  TIME_PER_HOUR PT_TYPE  PT_CODE  TOTAL_TAP_IN_VOLUME  \
# 2     2021-01  WEEKDAY              8     BUS    64179                    1
# 38    2021-01  WEEKDAY              8     BUS    27129                   43
# 40    2021-01  WEEKDAY              8     BUS    52171                 1730
# 50    2021-01  WEEKDAY              8     BUS    46361                  250
# 68    2021-01  WEEKDAY              8     BUS    25461                    6
#
#     TOTAL_TAP_OUT_VOLUME  NET_MOVEMENT
# 2                     56            55
# 38                   705           662
# 40                   738          -992
# 50                   385           135
# 68                   269           263

# %%
weekday_am_peak.to_csv(r"C:\Users\ytxu\Documents\ArcGIS\Projects\GE6211SDH\LTA Data Mall\DYNAMIC\transport_node_bus_202101\WEEKDAY_AM_PEAK_202101.csv",sep=',')

# %%
weekday_pm_peak = weekday[weekday['TIME_PER_HOUR']==18]
weekday_pm_peak.head()
# Out:
#     YEAR_MONTH DAY_TYPE  TIME_PER_HOUR PT_TYPE  PT_CODE  TOTAL_TAP_IN_VOLUME  \
# 129    2021-01  WEEKDAY             18     BUS    24519                  169
# 137    2021-01  WEEKDAY             18     BUS    77119                   62
# 154    2021-01  WEEKDAY             18     BUS    45389                  111
# 243    2021-01  WEEKDAY             18     BUS    25099                  264
# 277    2021-01  WEEKDAY             18     BUS     5421                  449
#
#      TOTAL_TAP_OUT_VOLUME  NET_MOVEMENT
# 129                  2035          1866
# 137                     3           -59
# 154                  1088           977
# 243                    51          -213
# 277                   205          -244

# %%
weekday_pm_peak.to_csv(r"C:\Users\ytxu\Documents\ArcGIS\Projects\GE6211SDH\LTA Data Mall\DYNAMIC\transport_node_bus_202101\WEEKDAY_PM_PEAK_202101.csv",sep=',')
